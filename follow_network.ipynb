# %% [markdown]
# ### Creating Network of hashtags based on followers relationships

# %% [markdown]
# Steps:
# 1. directed follower network from user to user
# 2. get videos of each user
# exclude if user has no hashtags in their videos
# 3. use tf-idf on hashtags from all user videos and exctract the most significant ones
# function = hashtags of user
# 4. create directed network of hashtags
# 5. direction from hashtags of the follower to hashtags of the folowed

# %%
import json
import pandas as pd
import requests
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
import pickle

# %%
follows = pd.read_csv('../shared-folder-gald/data/follow-link.csv')

# %%
videos = pd.read_json('../shared-folder-gald/data/video-creators.json')

# %%
videos.head()
# Out:
#                    username  \
# 0      the.animal.holocaust
# 1         bakemehealthylove
# 2               livinapril7
# 3  goodvibessocietyofficial
# 4               settonfarms
#
#                                    video_description region_code  share_count  \
# 0  Replying to @ov10bronco #dominicizrealmyers #v...          US            4
# 1  How to make: 1. Get Your Mix: Grab our Oatmeal...          US            4
# 2  Looking for a healthy #plantbased #protein pac...          US            0
# 3  Pull up to Sprouts, grab those good vibes bott...          US            0
# 4  At Setton Farms, we are committed to sustainab...          US            1
#
#                                        hashtag_names                   id  \
# 0  [vegan, yes, bbq, meat, carnivore, govegan, ve...  7274212644502998314
# 1  [wafflemix, waffleday, plantbased, strawberryw...  7271102720256314666
# 2  [food, healthy, lunch, health, salad, tasty, o...  7272105378920353054
# 3  [drinks, weekendvibes, sprouts, plantbased, su...  7271427012529524011
# 4  [nuts, recipe, farm, farmlife, harvest, pistac...  7273980908565433646
#
#    like_count      music_id  view_count  \
# 0          40  7.274213e+18        1054
# 1          65  7.217848e+18        1087
# 2           2  6.705026e+18         271
# 3          31  7.271427e+18         372
# 4         120  7.133309e+18        7031
#
#                                        voice_to_text  comment_count  \
# 0  You say, why torture yourself? Because all we ...          181.0
# 1  Happy National Waffle Day we're celebrating wi...            0.0
# 2                                                NaN            0.0
# 3                                                NaN            2.0
# 4                                                NaN            2.0
#
#           create_time  cluster    cluster-label  playlist_id effect_ids
# 0 2023-09-02 13:00:37       10  Healthy Cooking          NaN        NaN
# 1 2023-08-25 03:52:14       10  Healthy Cooking          NaN        NaN
# 2 2023-08-27 20:43:20       10  Healthy Cooking          NaN        NaN
# 3 2023-08-26 00:50:41       -1         Outliers          NaN        NaN
# 4 2023-09-01 22:01:08        8        Gardening          NaN        NaN

# %%
hashtags_to_remove = set([
    'hashtag', 'fyp', 'foryou', 'foryoupage', 'fypシ', 'viral', 'love',
    'trending', 'tiktok', 'funny', 'fypage', 'capcut', 'duet', 'news',
    'foryourpage', 'fy', 'fypシ゚viral', 'follow', 'viralvideo', 'like',
    'trend', 'stitch', 'video', 'lol', 'instagram', 'asmr', 'explorepage',
    'instagood', 'viraltiktok', 'youtube', 'share', 'new', '2023', 'reels',
    'followme', 'vlog', 'satisfying', 'viralvideos', 'wow', 'funnyvideos',
    'repost', 'relatable', 'followforfollowback', 'breakingnews', 'storytime',
    'tiktokfamous', 'greenscreenvideo', 'for', 'foru', 'tiktoktrend', 'goviral',
    'bhfyp', 'viralpost', 'f', 'tiktoker', 'fypp', 'fyppppppppppppppppppppppp',
    'tiktokviral'
])

# Function to remove unwanted hashtags
def clean_hashtags(hashtags):
    if isinstance(hashtags, list):  # Ensure it's a list
        return [tag for tag in hashtags if tag not in hashtags_to_remove]
    return hashtags  # Return as-is if not a list

# Apply the cleaning function
videos['hashtag_names'] = videos['hashtag_names'].apply(clean_hashtags)

# Display the cleaned dataframe
print(videos[['hashtag_names']].head())
# Out:
#                                        hashtag_names
# 0  [vegan, yes, bbq, meat, carnivore, govegan, ve...
# 1  [wafflemix, waffleday, plantbased, strawberryw...
# 2  [food, healthy, lunch, health, salad, tasty, o...
# 3  [drinks, weekendvibes, sprouts, plantbased, su...
# 4  [nuts, recipe, farm, farmlife, harvest, pistac...

# %%
user_videos = {}
for index, row in videos.iterrows():
    user_videos.setdefault(row['username'], []).append(row['id'])

# %% [markdown]
# filter the videos by users that exist in the follower database

# %%
usernames_unique = pd.unique(follows[['source', 'target']].values.ravel()).tolist()
usernames_unique
# Out:
# ['designs_from_time',
#  'cosmicsummit',
#  'conspiracyhubog',
#  'guildworld',
#  'venetialamanna',
#  'i_d',
#  'texasbeeworks',
#  'dcopperman',
#  'healthyholistichomes',
#  'maxlamanna',
#  'thatcurlytopp',
#  'zainab.slow.fashion',
#  'politicsjoe',
#  'tedtoks',
#  'bbcnews',
#  'lois1xblue',
#  'vicenews',
#  'andreacheong_',
#  'nssmagazine',
#  'iobservefashion',
#  'nowthisearth',
#  'billnye',
#  'worldeconomicforum',
#  'gardenmarcus',
#  'pelacase',
#  'okczoo',
#  'alexisnikole',
#  'greenpeace_international',
#  'onetreeplanted',
#  'wwf',
#  'newscientist',
#  'kirasabin',
#  'havrestudio',
#  'earthrise.studio',
#  'cristinamantas',
#  'farmer_nick',
#  'flourishingmother',
#  'joycelynlongdon',
#  'iamtabithabrown',
#  'herbifoods',
#  'minimalistbaker',
#  'browngirlgreen',
#  'pxgon',
#  'sustainthemag',
#  'aditimayer',
#  'nataliatrevinoamaro',
#  'swansonsfabrics',
#  'stopbigoil',
#  'ethiqueworld',
#  'xiyebastida',
#  'siranda_manchez',
#  'domipalmer',
#  'maggie_zhou',
#  'ouryouth4theclimate',
#  'ecofran',
#  'thehellajam',
#  'judybaogarden',
#  'goingzerowaste_',
#  'green4ema',
#  'mikaelaloach',
#  'shopberriez',
#  'santosbymonica',
#  'diandramarizet',
#  'imperfectidealist',
#  'twinbrett',
#  'mona.gems',
#  'climatediva',
#  'rcgdglobal',
#  'sustainablebaddie',
#  'karlakdepina',
#  'finds.world',
#  'sustainablesabs',
#  'redleafranch',
#  'andagainco',
#  'mila_sullivan',
#  'thetrashwalker',
#  'johnapabon',
#  'mspaulapresents',
#  'sophfei',
#  'mayasideas',
#  'zbtheclimateoptimist',
#  'jacobsimonsays',
#  'iam_samata',
#  'relauren',
#  '_kellydempsey_',
#  'jhanneu',
#  'victoriahammett',
#  'helloarielchristine',
#  'acteevism',
#  'c4news',
#  'earthtopia',
#  'abcnews',
#  'nowthis',
#  'joelbervell',
#  'pattrn',
#  'tofology',
#  'glblctzn',
#  'pbs',
#  'malalafund',
#  'weatherchannel',
#  '4ocean',
#  'dr.katharine',
#  'attn',
#  'thegarbagequeen',
#  'bbcnewsround',
#  'tanner.leatherstein',
#  'jordantalexander',
#  'sign_ofthetimes',
#  'yasminfurmie',
#  'zanelemji',
#  'amyodellwriter',
#  'matteroftrust',
#  'genzforchange',
#  'nytimes',
#  'wwf_uk',
#  'terracyclehq',
#  'tarabellerose',
#  'fairearthfoundation',
#  'heated.world',
#  'camwhitnall',
#  'parleyfortheoceans',
#  'thrillist',
#  'elisejoshi',
#  'waterhaul',
#  'action4climate',
#  'tncnaturelab',
#  'oc_namibia',
#  'climatepower',
#  'independent',
#  'guardian',
#  'eveningstandard',
#  'guardianaustralia',
#  'dailymail',
#  'omnivorousadam',
#  'joemyheck',
#  'theshilohfarm',
#  'vego_garden',
#  'creative_explained',
#  'quickthoughtpodcast',
#  'curlycultivators',
#  'loveofearthco',
#  'brightly.eco',
#  'teachgogreen',
#  'environmentalish',
#  'simpleenvironmentalist',
#  'zeroishwaste_vegan',
#  'jessicahaizman',
#  'kleankanteen',
#  'juulian.c',
#  'sustainablecherub',
#  'jess.cliftonn',
#  'ellianarapalli',
#  'worthnotwaste',
#  'asmalllife',
#  'lachikisaly',
#  'eco_og',
#  'earthstewardess',
#  'turnipvegan',
#  'margreen_s',
#  'traashboyyy',
#  'theblythebasics',
#  'thewildflowerdances',
#  'laura_bruj',
#  'mindful_mending',
#  'oneofahivecandles',
#  'shelbssays',
#  'tyrjohnnn',
#  'maryelouis',
#  'beejoyfuljess',
#  'tine_hancke',
#  'shelbizleee',
#  'lottiedalziel',
#  'melissa.brandle',
#  'nycnichole',
#  'mckensea',
#  'emmajanegeisler',
#  'the_happihippi',
#  'ansley_vaughan',
#  'trashcaulin',
#  'comewhatmayjor',
#  'sciencebyashley',
#  'chelsychristina',
#  'brennan.kai',
#  'consciousco_',
#  'thethriftythinker',
#  'julianadeliberais',
#  'intertidalkendy',
#  'andriana_marine',
#  'fansiefriperie',
#  'almondcow',
#  'meggrowsplants',
#  'motemarinelab',
#  'alex.haraus',
#  'forrestgalante',
#  'blueland',
#  'mndiaye_97',
#  'cleanthisbeachup',
#  'marinemammalcare',
#  'nicekidd',
#  'prothearctic',
#  'sealrescueireland',
#  'sambentley',
#  'griffwild',
#  'fascinatedbyfungi',
#  'chefpriyanka',
#  'homegrownnationalpark',
#  'aimee.7.7.3',
#  'ajplus',
#  'indigosfashions',
#  'thekoreanvegan',
#  'veganhackspod',
#  'nativeplanttok',
#  'bethanycosentino',
#  'cleancreatives',
#  'positivelygreenliving',
#  'cnn',
#  'drilledmedia',
#  'bbcearth',
#  'rainforestactionnetwork',
#  'dreroq',
#  'futureswell',
#  'cleanupaustralia',
#  'theclimatecouncil',
#  'jessicakleczka',
#  'fossilfreelondon',
#  'greenpeaceusa',
#  'sustainablefashionfriend',
#  'gittemary',
#  'dr_gilbz',
#  'samiahurstmajno',
#  'ausconservation',
#  'progressntwrk',
#  'greatsouthernreef',
#  'theoceancleanup',
#  'girlplusenvironment',
#  'greenpeace.de',
#  'greenpeaceafrica',
#  'commons.earth',
#  'bloombergopinion',
#  'kurz_gesagt',
#  'greenpeaceph',
#  'motherjonesmag',
#  'ecosia',
#  'greenpeaceap',
#  'debtforclimate',
#  'projectplanetaus',
#  'chilli.app',
#  'ausgeo',
#  'dolphin_project',
#  'climateandtransit',
#  'oxfamaustralia',
#  'samforchange',
#  'greenpeacenz',
#  'andrew_the_arborist',
#  'thephoenixconservancy',
#  'goinggreenmedia',
#  'insureourfuture',
#  'onegreenthing',
#  'dw_planeta',
#  'padi',
#  'makepolluterspay',
#  'bodhi_patil',
#  'dougmcneall',
#  'livekindly',
#  'sunrisemvmt',
#  'movebeyondcoal',
#  'greenpeaceuk',
#  'scotpilie_wx',
#  'aljazeeraenglish',
#  'abcnewsaus',
#  'all_about_climate',
#  'lifebeforeplastic',
#  'yardfarmer.co',
#  'greenpeacemy',
#  'nudibranch_nerd',
#  'briannemwest',
#  'thehuntington',
#  'octaviachill',
#  'hilatheearth',
#  'thenatureconservancy',
#  'playersfortheplanet',
#  'climatereality',
#  'arbordayfoundation',
#  'bowercollective',
#  'wateraid',
#  'sustainablehaus',
#  'selfhelpafrica',
#  'treehousebus',
#  'americanredcross',
#  'theclimateinitiative',
#  'oneearthofficial',
#  'bigcitygardener',
#  'future_explored',
#  'wwf_ch',
#  'wwfsg',
#  'artebiel',
#  'sollysundries',
#  'vintagestockreserve',
#  'jesscraven101',
#  'artbypacoway',
#  'natepetroski',
#  'tdotbdot',
#  'withlovelenny',
#  'lifetaketwo',
#  'shaynateresetaylor',
#  'bella.venice',
#  'maria_and_alexandra',
#  'oddmuselondon',
#  'momentsabloom',
#  'wornvintage',
#  'matildabeaa',
#  'itvnews',
#  'sunnraayy',
#  'itsseeingdouble',
#  'murlongcres',
#  'fvlyacelik',
#  'jasminedarya',
#  'roseinc',
#  'global_witness',
#  'daughters4earth',
#  'climeradar',
#  'blkgirlenvironmentalist',
#  'joi.lee',
#  'blackearthpodcast',
#  'plantbasednews',
#  'forceofnature.xyz',
#  'jungleculture.eco',
#  'veganuary',
#  'veganbeautygirl',
#  'gndrising',
#  'iamjeromefosterii',
#  'coralgardeners',
#  'ethicalunicorn',
#  'impakter.eco',
#  'briefbutspectacular',
#  'extinction.rebellion.dc',
#  'oxfamgb',
#  'louisvithenatureguy',
#  'future__earth',
#  'seashepherdglobal',
#  'justkeepthinking',
#  'niamhmackinnon',
#  'idabenoni',
#  'chef_tristan_welch',
#  'lukebeasleyofficial',
#  'laurafayeten',
#  'earthnailsandtails',
#  'solarpunkfarmer',
#  'gardenary',
#  'afteralwaysapparel',
#  'acorn_land_labs',
#  'kamoka_pearl',
#  'homegrown_handgathered',
#  'thelocalproject',
#  'thermalandoaks',
#  'thriftedgent',
#  'michaelkosta_',
#  'tryboredcow',
#  'grace.roots.gardening',
#  'the_garden_is_growing',
#  'vikkifromjersey',
#  '1890_homestead',
#  'lex.delarosa',
#  'homewithmadison',
#  'homesteading_mama_',
#  'livingunconventionally',
#  'the.wombwitch',
#  'lotustrolleybag',
#  'amethystfoodforest',
#  'uncensored_bee',
#  'sarahwildmothering',
#  'dariasavaya',
#  'farmboyjames',
#  'cakesbody',
#  'amateurfoodalchemist',
#  'mirendarosenberg',
#  'grassfedgirliee',
#  'angelluke777',
#  'vagabondartist',
#  'jonnynature1',
#  'jimr9057z2e',
#  'highfrequencies',
#  'australianmarinecons',
#  'ryangle3000',
#  'whales_org',
#  'pakalologirl420',
#  'earth.stories',
#  'localoceanco',
#  'katmabu',
#  'markenzycesar',
#  'northwoodsbarbie',
#  'cbseveningnews',
#  'doctorswithoutborders',
#  'lovetheoceansofficial',
#  'oceanmimic',
#  '_shay.love',
#  'marine.bio.john',
#  'mykemollard',
#  'divernow',
#  'bp.underwater',
#  'theoctopusguy',
#  'nautiluslive',
#  'divearizona',
#  'diverkatt',
#  'island_aloha',
#  'camperhacker',
#  'kilikanaka',
#  'perksofbuildingtiny',
#  'diverbliss',
#  'taysperry',
#  'azul.unlimited',
#  'janinarossiter',
#  'theamericanforester',
#  'lakelocked_wildman',
#  'gma',
#  'gingerzee',
#  'petamarine',
#  'projecthiu',
#  'sealegacy1',
#  'whalesorg',
#  'lewispughfoundation',
#  'savetheseaturtlesinterna',
#  'seashepherdaustralia',
#  'oneoceanresearch',
#  'financialfoxhole',
#  'climatetown',
#  'antontreuer',
#  'alternativelivingspaces',
#  'goodman.lafon',
#  'okwildlifedept',
#  'capeclasp',
#  'sofishtication',
#  'scripps_oceanography',
#  'mysticseaportmuseum',
#  'blueoceansociety',
#  'sr3sealife',
#  'miss_elasmo',
#  'whale_detective',
#  'theplantprof',
#  'davebondy',
#  'fitshortie',
#  'spaceweatherlady',
#  'info_4_you',
#  'wick3dweather',
#  'mateo.zielonka',
#  'gatorchris1',
#  'drift0rtv',
#  'bklahm',
#  'tahnmiller',
#  'heraldsun_',
#  'myradarwx',
#  'jillian_rn4',
#  'uede.art',
#  'masterreefguides',
#  'masonkuhr',
#  'gypsyremains50',
#  'eatthecountry',
#  'bamwx',
#  'foxweather',
#  'weatherdaddy',
#  'captainplanetbackup',
#  'misfitmeteorologist',
#  'weatherondafly',
#  'reedtimmerwx',
#  'jpall20',
#  'praxisofbootes',
#  'kulanui_',
#  'unitedwestandstrike',
#  'jacob__knowles',
#  'deadeye2tongues',
#  'reef_org',
#  'oneoceansharks',
#  'retetielephants',
#  'oliveridleyproject',
#  'therecount',
#  'wildnativelady',
#  'ana_banana4130',
#  'paintedblackdecor',
#  'thenationalnews',
#  'illuminatives',
#  'spirit_talkers',
#  'ghoststacks',
#  'ghostcitytours',
#  'designsbymckay',
#  'thehausethrifter',
#  'ystreetstudio',
#  'che.jim',
#  'tiktalkpaiute',
#  'straightouttasalem',
#  'spicymoustache',
#  'scratcher_girls',
#  'fromdreamtoseed',
#  'theresarubalcava1',
#  'middleeasteye',
#  'no_dilemma',
#  'rose_under_cypresses',
#  'brokenbakey',
#  'belovedcabin',
#  'bakedgardening',
#  'destroykasmin',
#  'mozartgabrielofficial',
#  'djjezmundo',
#  'cbsmornings',
#  'cbsnews',
#  'facethenation',
#  'icrc',
#  'ilo',
#  'changedotorg',
#  'ageinternational',
#  'kidsgastrodoc',
#  'francescaapage',
#  'rebecca_saltysea',
#  'dlogamez',
#  'heathermmaynard',
#  'josephabrassey',
#  'kylee_rullo',
#  'blitzphd',
#  'barefootgurlz',
#  'askjordon',
#  'janellemonet_',
#  'gabbertttt',
#  '12tides',
#  'maddy.mermaid',
#  'coexistprojects',
#  'conservation_kate',
#  'officialguyharvey',
#  'gracie.harriss',
#  'oceankatrinaa',
#  'invertebabe',
#  'flukesandfins',
#  'floridaguidejosh',
#  'robchapmanfishing',
#  'marineb1ologist',
#  'goprograndpa',
#  'eco.aly',
#  'oneoceandiving',
#  'b2badventures',
#  'dengcusv384',
#  'valentine_thomas',
#  'vincekleinn',
#  'ugreen_us',
#  'magicalaquatic',
#  'bulesampah',
#  'juansharks',
#  'divethecave',
#  'godivesa',
#  'trinepscuba',
#  'edwinn_eatz',
#  'preciousplasticmonash',
#  'simplyplasticfreeau',
#  'littlebrrmaid',
#  'zoe_kean_sci',
#  'o.fish.al_dirtydur',
#  'geekecology',
#  'whitesharkocean',
#  'friendliestcatch',
#  'kanyanawildlife',
#  'thehiddenseawine',
#  'foreverreefproject',
#  'inthesport.co',
#  'mick_fullerton_wildlife',
#  'defendthe.wild',
#  'barky.bakey',
#  'itzjoshuajake',
#  'campingboatingfishingfun',
#  'aquanauta_diver',
#  'thatflowerchick09',
#  'trashbandikoot',
#  'scubadivingmag',
#  'reeflifediveshop',
#  'sharkabcabc',
#  'rentmount',
#  'sharkeatsajax',
#  'never2oldsd',
#  'simkern',
#  'calbinogenome',
#  'hiphopscienceshow',
#  'oceanfilly',
#  'mermaidcasey',
#  'seafloorscience',
#  'letsmakethempay',
#  'marinebiotok',
#  'ocean_institute',
#  'blackinmarinescience',
#  'thehappybroadcast',
#  'iubloomington',
#  'oneoceanconservation',
#  'weareuni',
#  'thepalmbeaches',
#  'oceangalzz',
#  'saltylocs',
#  '__madeforit__',
#  'arnauargon',
#  'cindy_rostron',
#  'bhumi_organic_cotton',
#  'adventurous_elle',
#  'wild.family.life',
#  'maria_seandme',
#  'integral_chemistry',
#  'autoimmunityawareness',
#  'alternativehouses',
#  'offgrid_power',
#  'ausbackpacker',
#  'six_inabus',
#  'simone_stewart',
#  'kaderfolles',
#  'papagovans',
#  'indi_van_a_jones',
#  'bunnyandbeyond',
#  'tinyhouse_inspiration',
#  'tomandfordythevan',
#  'thecoconettv_',
#  'topdidj',
#  'itzltiozelotl',
#  'we_r_native',
#  'renewsnz',
#  'eco.mindful.lei',
#  'thestorytimeguy',
#  'julio_tuki',
#  'mrcrim3',
#  'africanheritagecity',
#  'picpacific',
#  'joerauth_',
#  'bagelfinagle',
#  'extremeofficial',
#  'sustainablymanaged',
#  'njoutdooradventures',
#  'slimkimxo',
#  'projectpermacultura',
#  'nomeatdisco',
#  'bed.threads',
#  'vaydamaher',
#  'steelbradnolia',
#  'beccybotanica',
#  'cierrawardell',
#  'the.tiser',
#  'thesubpod',
#  'melmelbourne_',
#  'abc',
#  'my_plastic_free_home',
#  'whitehomeonwheels',
#  'cast_iron_chris',
#  'maddyoutdoors',
#  'veggiemama95',
#  'tanyaplibersek',
#  'glowdiaries___',
#  'alisonistoxinfree',
#  'renowayoflife',
#  'cazincthelabel',
#  'linnea.and.akela',
#  'ashs.backyardgarden',
#  'the_gretaway',
#  'thesaturdaypaper',
#  'chef_bai',
#  'dailytelegraph',
#  'shianneodonoghue',
#  'sofialigeros',
#  'bookenblend',
#  'bakedbymelissa',
#  'axeandroothomestead',
#  'thediyist',
#  'chefreillymeehan',
#  'kt.burdett',
#  'thelaceyclub',
#  'modernruralcivilian',
#  'urbanlist',
#  'drivebypatch',
#  'thedailyaus',
#  'greenfingeredcityboy',
#  'recipes',
#  'abby.joselyn',
#  'twoobs',
#  'nudiwear',
#  'alexinwaterlust',
#  'kay_odonnell',
#  'oseamalibu',
#  'onyxwhy',
#  'sarahyak_',
#  'swimpupp88',
#  'itschefalison',
#  'theexcitablescientist',
#  'soalliance',
#  'happy_divers',
#  'luisorozcoa',
#  'rachel.brooks.art',
#  'mantatrust',
#  'ienearth',
#  'planettodaypod',
#  'beholdnatalia',
#  'whatsupcv',
#  'saugatuckdunes',
#  'westernwatergirl',
#  'kenthiccer',
#  'jaredranahan',
#  'dance4love2grow',
#  'darastarrtucker',
#  'gabnaturalist',
#  'mrdirago',
#  'cagovernor',
#  'western.priorities',
#  'nativeplantforyou',
#  'restorethedelta',
#  'genesisfix',
#  'theaaronmurphy',
#  'demgovs',
#  'lucasthelorax',
#  'conservationnerd99',
#  'thetwitchybotanist',
#  'qasim.rashid',
#  'amazonteamorg',
#  'mollykawahata',
#  'housepuritty',
#  'fireandsalt',
#  'pedestriandignity',
#  'fdmarketco',
#  'imbaela',
#  'climatereadyhome',
#  'dexter.mp4',
#  'birdmanwrenn',
#  'donnalikesplants',
#  'ticks_of_tiktok',
#  'climatehuman',
#  'robecs',
#  'molesrcool',
#  'shopyouer',
#  'big_country3030',
#  'kingsofebay',
#  'theregrowthproject',
#  'stonesaquaticweed',
#  'deeranddeerhunting',
#  'thatokbiologist',
#  'stelbailey',
#  'hunting_appalachia',
#  'prophet.jeremiah',
#  'joshuadairen',
#  'dailymailau',
#  'wildland_firefighter912',
#  'ukuspolitics',
#  'js.goldklang',
#  'therealgorillaboy',
#  'accuweather',
#  'wallacewarthog',
#  'davidpakmanshow',
#  'snowravenofficial',
#  'commie_trucker',
#  'michiganlcv',
#  'laistofficial',
#  'troutunlimited_',
#  'mylifeisanrpg',
#  'ecoshika',
#  'whaleswee',
#  'climatedefiance',
#  'spadaniel44',
#  'foodforestgoddess',
#  'fiveacresoffreedom',
#  'vivid_badger',
#  'bravewildernessnetwork',
#  'foodiechina888',
#  'wyattecoyote',
#  'theshadyecologist',
#  'elisabeth_kk',
#  'jeffhyer',
#  'teslaspacex',
#  'whatthefrogdoin716',
#  'tomorrows_trees',
#  'charlyrosey',
#  'tttornadoes',
#  'zaharieiulian',
#  'pierro_freebord',
#  'extremehangout',
#  'nadinezidani1',
#  'foresthideaway_',
#  'theoffgridguru',
#  'modernday_snowhite',
#  'wvrcfm',
#  'itsjustmecorbing',
#  'growing_edible_plants',
#  'thepowercompany',
#  'johnstossel',
#  'babylonbee',
#  'melosapothecary',
#  'maybeehives',
#  'beecrazyapiary',
#  'goldenhivemead',
#  'poppletreecreekfarms',
#  'autumnfarms',
#  'boxofroxie',
#  'edgarthestormchaser',
#  'gardeningwithdezz',
#  'jamesbigleyranches',
#  'funsizebeekeeper',
#  'masonjarlifestyle',
#  'jt_entertains',
#  'beckduff',
#  'theyoungturks',
#  'carlyburd43',
#  'abc7ny',
#  'treeisalive',
#  'newsnationnow',
#  'heatherfeather32694',
#  'diva_dee25',
#  'surfsupfinds',
#  'megclectic',
#  'vegan_warrioresse',
#  'incrediberry',
#  'typsyflypsy',
#  'keeneyacre',
#  'heavydsparksvid',
#  'thefactispodcast1',
#  'genzfighting',
#  'jennystojkovic',
#  'nbcnewyork',
#  'miamiherald',
#  'mellowstate',
#  'twinsdaddy.b',
#  'boldnorth_flips',
#  'youcoontsseeme',
#  'ringoffiremedia',
#  'outlandish_fam',
#  'faithsfresh',
#  'cowboy_woolboy',
#  'gurridyula',
#  'inspire.humanity',
#  'lifegoalinvestments',
#  'greg_price11',
#  'cnetdotcom',
#  'newsforthought',
#  'realclaytonmorris',
#  'nonothenono.eth',
#  '_saramorris',
#  'dsblanke',
#  'dieuxskin',
#  'harborwildwatch',
#  'complicated_lyfe',
#  'kassi_lazzuri',
#  'vestiairecollective',
#  'retrotoyenvy',
#  'raikenprofit_official',
#  'convertedcloset',
#  'corylusj3',
#  'chelseaasoflate',
#  'chrisatpeak',
#  'daysofkay',
#  'utopia.us',
#  'thriftblackgrl',
#  'julietsfinds',
#  'thewildamalia',
#  'wanderren',
#  'itslinamar',
#  'kalemyname',
#  'aotearoaliberationleague',
#  'pique_action',
#  'charlesriverwatershed',
#  'saadia___m',
#  'juliancauzae',
#  'mediawise',
#  'bostopianews',
#  'ariellevking',
#  'dantethehater',
#  'intheloopresale',
#  'goodpplinc',
#  'thousandfell',
#  'sustaintheculture',
#  'azurefarm',
#  'miramaven',
#  'theearlyrisebaker',
#  'thebigfavorite',
#  'gardeningandgrowing',
#  'vespresounds',
#  'regenerativefarmers',
#  'urbanbackyardfarmer',
#  'northwoodsfolk',
#  'petecooperwildlife',
#  'yarnandthyme',
#  'cheesesgarden',
#  'grandtrinedesigns',
#  'seafoodsweetheart',
#  'andrew.millison',
#  'thequirkylamb',
#  'superhumanco',
#  'rileys.musings',
#  'avocado_bella',
#  'honeylunehivery',
#  'shelleycarline_design',
#  'swestman59',
#  'compostfairy',
#  'onecrafdiygirl',
#  'miguelsgarden_',
#  'fiddlersgreenfarmvt',
#  'strongerroots',
#  'mulchitover',
#  'dinasdays',
#  'gardenzaddy',
#  'beeoasisllc',
#  'notjustgreenfingers',
#  'fauxsteadingmelbourne',
#  'theresadancing',
#  'sustainyourselfshop',
#  'ellenmarygardening',
#  'floricultgardens',
#  'from_the_garden',
#  'nyrestorationproject',
#  'marciedawnn',
#  'joeyplantstrees',
#  'crestviewcottage',
#  'mrstardis',
#  'sow.with.a.hoe',
#  'centerforfoodsafety',
#  'somewhatsustainable',
#  'apricothouseflowers',
#  'wanderspacefarm',
#  'americanarbitrage',
#  'fishydaddy',
#  'celticmanta',
#  'science_is_real',
#  'mostlymarine',
#  'seawitchbotanicals',
#  'nationallobsterhatchery',
#  'bipoc_outdoors',
#  'zethdafer',
#  'environerd',
#  'dontforgetthesnacks',
#  'seattleaquarium_official',
#  'goodtripadventures',
#  'theplanktonproject',
#  'emilythemarinebiologist',
#  'seadocsociety',
#  'elementologydesigns',
#  'thedowneastcowboy',
#  'aqniagara',
#  'nerdy_nicole97',
#  'paleo.chic',
#  'adropintheoceanshop',
#  'shellebrate_life',
#  'healthebayaquarium',
#  'gnar_science',
#  'celialeto2',
#  'headedanywhere',
#  'biologistimogene',
#  'mike_4_prez',
#  'coolguyzachary',
#  'yahoonews',
#  'leftmright',
#  'wearepushblack',
#  'allitav',
#  'hausdahlia',
#  'trudymharmon',
#  'shellyxudesign',
#  'dani.elle.marie',
#  'lucky.sweater',
#  'findsinthecity',
#  'nashvilleabigail',
#  'vic.ashton',
#  'supervickychicago',
#  'whimsysoul',
#  'smartglamour',
#  'pluseve',
#  'metalromantic',
#  'peppergrandcoulee',
#  'awomancalledgeorge',
#  'becmapes',
#  'restyleliving',
#  'rileysgrotto',
#  'electricgoodies',
#  'eternally.nomadic',
#  'doubleminted',
#  'airinjbarnett',
#  'fox_and_shrew',
#  'vintageearthllc',
#  'thrifttherapystyle',
#  'katieerobinson_',
#  'house.of.curiosities',
#  'slowfashionwardrobe',
#  'charitycopped',
#  'meredithmlynch',
#  'rickstrom',
#  'neuro_d_teacher1',
#  'ndcpoetry',
#  'dave_the_viking',
#  'alicollinsproductions',
#  'theabbyhoy',
#  'fiercefatfemme',
#  '_cccara',
#  'poppyluclothing',
#  'thevanitycase',
#  'halesbbee',
#  'affectionatelyaudrey',
#  'reflectivelybeth',
#  'maddiethethrifter',
#  'chelsthrifts',
#  'groarkboysbbq',
#  'southern_treasures',
#  'thriftingtreasure',
#  'bearded_thrifter',
#  'kaywayshop',
#  'tokyo_thrifts',
#  'freedom_hustler',
#  'shawnryanshow',
#  'fayedelanty',
#  'straitnochase1',
#  ...]

# %% [markdown]
# Get dictionary of hahtags per user

# %% [markdown]
# Using TF-IDF (Term Frequency-Inverse Document Frequency) to determine the most important hashtags for each user based on their videos.

# %% [markdown]
# Plan:
# 1. Convert user_videos into a format suitable for TfidfVectorizer.
# 2. Compute TF-IDF scores for hashtags within each user’s videos.
# Compute TF-IDF: Treat each user as a "document" and their hashtags as "terms".
# 3. Select top hashtags per user based on importance.
# 4. Append those hashtags to your dictionary.

# %%
# Initialize an empty dictionary to store user -> hashtags
user_hashtags = {}

for user, videos in videos.groupby('username'):  # No need for iterrows()
    all_hashtags = []
    
    for _, row in videos.iterrows():  # Now iterating rows correctly
        all_hashtags.extend(row['hashtag_names'])  # Add hashtags from each row
    
    # Store the concatenated hashtags in the dictionary
    user_hashtags[user] = all_hashtags

# %%
# Convert usernames_unique to a set for faster lookups (O(1) instead of O(n))
usernames_unique_set = set(usernames_unique)

# Filter dictionary: Keep only users in usernames_unique
filtered_user_hashtags = {user: videos for user, videos in user_hashtags.items() if user in usernames_unique_set}

# %%
#number of creators is smaller after filtering by the follow list
print(len(list(filtered_user_hashtags.keys())))
# Out:
# 13867

# %%
user_hashtag_text = {user: " ".join(hashtags) for user, hashtags in filtered_user_hashtags.items()}
print(user_hashtag_text)

# %%
from collections import Counter

# Flatten all hashtags and count occurrences
hashtag_counts = Counter(tag for tags in user_hashtag_text.values() for tag in tags.split())

# Keep hashtags appearing at least 3 times
frequent_hashtags = {tag for tag, count in hashtag_counts.items() if count >= 3}

# Filter hashtags in user_hashtag_text
filtered_user_hashtag_text = {
    user: " ".join([tag for tag in hashtags.split() if tag in frequent_hashtags])
    for user, hashtags in user_hashtag_text.items()
}

# %%
# Step 2: Compute TF-IDF
vectorizer = TfidfVectorizer(max_features=100000)
tfidf_matrix = vectorizer.fit_transform(filtered_user_hashtag_text.values())

# %%
# Get feature names (hashtags)
feature_names = vectorizer.get_feature_names_out()

# Step 3: Extract Top Hashtags Per User
user_tfidf_scores = {}

for i, user in enumerate(filtered_user_hashtag_text.keys()):
    # Get TF-IDF scores for this user
    tfidf_scores = tfidf_matrix[i].toarray().flatten()
    
    # Rank hashtags by score
    top_indices = tfidf_scores.argsort()[::-1]  # Sort in descending order
    top_hashtags = [feature_names[idx] for idx in top_indices[:]]  # Get top 5 hashtags
    
    # Store in dictionary
    user_tfidf_scores[user] = top_hashtags
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Step 4: Append to Original Dictionary
user_hashtags = defaultdict(list)
for user, hashtags in user_tfidf_scores.items():
    user_hashtags[user].extend(hashtags)

# Convert to normal dictionary (optional)
user_hashtags = dict(user_hashtags)

# Output Example
print(user_hashtags)

# %%
import pickle

with open('user_hashtags.csv', 'wb') as f:
    pickle.dump(user_hashtags, f)

# %%
with open('user_hashtags.csv', 'rb') as f:  # 'rb' = read binary
    user_hashtags = pickle.load(f)

# %%
user_hashtags.keys()
# Out:
# dict_keys(['._._.jaysonkiogima_._._', '.alessandrarosa', '.bcole', '.cass.ervative5.0', '.e.liza.beth', '.giddyupboutique', '.ilovejellyfishh', '.jeune.espion', '.roadshow', '.salty.nomad', '.tarasina', '.utopiaisnow', '.webs.girl', '007outofcover', '0530jenserrano', '0_aviation_7', '0_r_i_o_n7', '0ddlyt3rr1fy1ng', '0nly_pans', '0p0lystyrene', '10gsocial', '10newsfirst', '1173182q55', '11thhourmsnbc', '1234elena214', '1234glitterstore', '126media', '12may17', '12tides', '1360truth', '13hollywood520', '15601470nru', '171ststreetgames', '1775.flag.this', '180shift', '180studios', '1890_homestead', '1972pandoy', '1984destiny1', '19980124zff', '19bigg84', '19xxcovey', '1damir_kee', '1hotels', '1lbclogo', '1loki3', '1maytweather', '1mooreshop', '1newsnz', '1rechelle', '1sgcal70', '1stblackmanukvillagetour', '1stdonoharm', '1wishywashyvegan', '2.0thrifts', '2000chevytahoe', '2000s.bbys', '2021sam2', '2024usa', '2050magazin', '20_years_ago_', '20shedidit21', '213raider76', '222ryles', '222virgoval', '23456faces', '26gallday', '280ackleyimproved', '2_gea_2', '2am22pm', '2brown2gaf', '2featherswoodworking', '2girlscallmemom', '2hand.magic', '2k_luxeco', '2ndlifeboutique', '2newsoklahoma', '2olfartsinthewoods', '2ravenfeathers', '305fishingline', '321_down_syndrome_kerry', '330everywhere', '345.fam', '34point4skincare', '350deschutes', '350nhaction', '350sac', '38degrees_uk', '3bmeteo_official', '3crazy.farm.girls', '3gungringo2.2', '3quarters.design', '3rdrockclothing', '3some.cz', '3wisdom6power9', '3wsgenerationsbeadwork', '4.the.love.of.purple', '438adonis', '4_junkremoval', '4aavm', '4bbrakajazza', '4myearth', '4myzen', '4ocean', '4orever1', '4thefoodie', '504_girl_', '5dmediagroup', '5forsparkling', '5gyres', '5mingardener', '5minute.decor.official', '5panjtan', '5tolifestudios', '605chaser', '66elibah389', '69bboutique', '6thnation716', '707reworked', '711hotdogs', '7191clothing', '72thearchitect', '7ampodcast', '7ierra0', '7newsq', '7rickor7rea7', '80schrisg', '81tikhub', '86plastic', '89kitykat', '8ballcustomvintage', '8dayseat', '8tcthrifts', '90babys03', '910.kbj', '96t.berlin', '99th_monkey', '_...unpopular..._', '_..unpopular98.._', '_.anishikwe.chrysi.bee._', '____jules_______', '____tyst', '__dreamcatcherz__', '__frump__', '__mackenziejones', '__madeforit__', '_abbyledet', '_aharrison65', '_alexanderrose', '_aliciavaldes_', '_allirahfisher', '_annaleni', '_ashhkardashh', '_averystudio', '_basicsusma', '_betor323', '_blondie_1', '_bugsrabbit', '_cal_cifer', '_carmenchristine', '_cccara', '_chebett', '_cleansea', '_cocobates', '_dantheram_', '_darrenjglenn_', '_econati_', '_elheis_', '_emmagarland_', '_erinlynn8', '_futurehippie', '_futureright', '_geotrek', '_gerry24_', '_glong', '_gothictae', '_grassland_beauty_', '_greengal', '_hannah_clift_', '_i.am.danu', '_ibuffy', '_immortal_vision', '_itstommy96', '_janellew', '_jesswilson_', '_johnsy', '_jordanfinds', '_k.l.e.b_', '_kaylakatie_', '_kellydempsey_', '_kuestenkind_im_herzen_', '_le_nomade_42', '_le_thi_', '_linyage_', '_lucy.official', '_m.o.j.o_', '_mace.com', '_mandm01_', '_manifestationlyfe_', '_mariaxoxo_', '_mhellowdee_', '_moses4lf', '_nativeamerica', '_nativesouls', '_nicole._.elizabeth_', '_not_the_one', '_pasta_now', '_peejamas', '_planeteco', '_prettywoman', '_purple_duck', '_r5010_', '_raxacoricofallapatorian', '_saramorris', '_scoopi.co', '_shay.love', '_sherridenise_', '_shoppursue', '_slacf_', '_solarbearenergy_', '_stay.aware_', '_stopthewillowprojectx', '_syrenea_', '_taaaryn', '_the_fallen_shunra_', '_theblessedhalls', '_thecampingmom', '_thewcs', '_traid', '_tshegofatso_precious', '_tstacks27', '_uncontrolled_chaos_', '_vegetarian_ish', '_verywell1', '_volverde_', '_yumbug', 'a.b.fritz.joy', 'a.breadpie', 'a.g834', 'a.l.t.a.training', 'a.new.americaa', 'a.riverrat', 'a.vizz', 'a.yazzie3', 'a1solarstore', 'a_lefty_gamer_2', 'a_texas_gal', 'a_thing_with_feathers', 'aah_aaaaah', 'aairabeclassy_', 'aamir.phd', 'aardeurbanfarms', 'aaron200995', 'aaron_coo ...
